# %% [markdown]
# <a href="https://colab.research.google.com/github/Ani-Michael/Emotional-prediction-in-Nigerian-music-using-deep-learning/blob/main/%20Final_My_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %% [markdown]
# Importing data from drive

# %%
import pandas as pd
df=pd.read_csv("/content/labeled_dataset.csv")
df.head(10)
# Out:
#                        name                         album  \
# 0                    Sparky            Mandy & The Jungle
# 1                shuga rush  EVERYTHING YOU HEARD IS TRUE
# 2                     LITT!                         LITT!
# 3  Confident / Feeling Cool               Enjoy Your Life
# 4                wanted you                         rare.
# 5                    Kasala                      Pioneers
# 6                   Pull Up             Everything Pretty
# 7              take a break                         rare.
# 8                      Cash               Enjoy Your Life
# 9                 SATISFIED                        GEMINI
#
#                 artist artist_top_genre  release_date  length  popularity  \
# 0        Cruel Santino  alternative r&b          2019  144000          48
# 1  Odunsi (The Engine)          afropop          2020   89488          30
# 2                 AYLØ        indie r&b          2018  207758          40
# 3           Lady Donli     nigerian pop          2019  175135          14
# 4  Odunsi (The Engine)          afropop          2018  152049          25
# 5          DRB Lasgidi     nigerian pop          2020  184800          26
# 6          prettyboydo     nigerian pop          2018  202648          29
# 7  Odunsi (The Engine)          afropop          2018  141933          27
# 8           Lady Donli     nigerian pop          2019  187714          36
# 9             Tay Iwar  alternative r&b          2019  123082          30
#
#    danceability  acousticness  energy  instrumentalness  liveness  loudness  \
# 0         0.666        0.8510   0.420          0.534000    0.1100    -6.699
# 1         0.710        0.0822   0.683          0.000169    0.1010    -5.640
# 2         0.836        0.2720   0.564          0.000537    0.1100    -7.127
# 3         0.894        0.7980   0.611          0.000187    0.0964    -4.961
# 4         0.702        0.1160   0.833          0.910000    0.3480    -6.044
# 5         0.803        0.1270   0.525          0.000007    0.1290   -10.034
# 6         0.818        0.4520   0.587          0.004490    0.5900    -9.840
# 7         0.808        0.6080   0.300          0.000048    0.0863   -11.213
# 8         0.846        0.2140   0.669          0.467000    0.0857    -7.822
# 9         0.555        0.9120   0.295          0.275000    0.0967   -11.038
#
#    speechiness    tempo  time_signature  emotion
# 0       0.0829  133.015               5  Neutral
# 1       0.3600  129.993               3  Excited
# 2       0.0424  130.005               4  Neutral
# 3       0.1130  111.087               4  Neutral
# 4       0.0447  105.115               4    Happy
# 5       0.1970  100.103               4  Neutral
# 6       0.1990   95.842               4  Neutral
# 7       0.0453  119.964               4  Neutral
# 8       0.0441  115.008               4  Neutral
# 9       0.0360   77.033               4  Neutral

# %%
df.describe()
# Out:
#        release_date         length  popularity  danceability  acousticness  \
# count    530.000000     530.000000  530.000000    530.000000    530.000000
# mean    2015.390566  222298.169811   17.507547      0.741619      0.265412
# std        3.131688   39696.822259   18.992212      0.117522      0.208342
# min     1998.000000   89488.000000    0.000000      0.255000      0.000665
# 25%     2014.000000  199305.000000    0.000000      0.681000      0.089525
# 50%     2016.000000  218509.000000   13.000000      0.761000      0.220500
# 75%     2017.000000  242098.500000   31.000000      0.829500      0.403000
# max     2020.000000  511738.000000   73.000000      0.966000      0.954000
#
#            energy  instrumentalness    liveness    loudness  speechiness  \
# count  530.000000        530.000000  530.000000  530.000000   530.000000
# mean     0.760623          0.016305    0.147308   -4.953011     0.130748
# std      0.148533          0.090321    0.123588    2.464186     0.092939
# min      0.111000          0.000000    0.028300  -19.362000     0.027800
# 25%      0.669000          0.000000    0.075650   -6.298750     0.059100
# 50%      0.784500          0.000004    0.103500   -4.558500     0.097950
# 75%      0.875750          0.000234    0.164000   -3.331000     0.177000
# max      0.995000          0.910000    0.811000    0.582000     0.514000
#
#             tempo  time_signature
# count  530.000000      530.000000
# mean   116.487864        3.986792
# std     23.518601        0.333701
# min     61.695000        3.000000
# 25%    102.961250        4.000000
# 50%    112.714500        4.000000
# 75%    125.039250        4.000000
# max    206.007000        5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530 entries, 0 to 529
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              530 non-null    object
#  1   album             530 non-null    object
#  2   artist            530 non-null    object
#  3   artist_top_genre  530 non-null    object
#  4   release_date      530 non-null    int64
#  5   length            530 non-null    int64
#  6   popularity        530 non-null    int64
#  7   danceability      530 non-null    float64
#  8   acousticness      530 non-null    float64
#  9   energy            530 non-null    float64
#  10  instrumentalness  530 non-null    float64
#  11  liveness          530 non-null    float64
#  12  loudness          530 non-null    float64
#  13  speechiness       530 non-null    float64
#  14  tempo             530 non-null    float64
#  15  time_signature    530 non-null    int64
#  16  emotion           530 non-null    object
# dtypes: float64(8), int64(4), object(5)
# memory usage: 70.5+ KB

# %% [markdown]
# Data processing

# %%
# Drop non-numeric columns that aren't useful for modeling
cols_to_drop = ['name', 'album', 'artist', 'artist_top_genre', 'release_date', 'length', 'popularity']
df_new_data = df.drop(columns=[col for col in cols_to_drop if col in df.columns], errors='ignore')

# %%
df_new_data.head(10)
# Out:
#    danceability  acousticness  energy  instrumentalness  liveness  loudness  \
# 0         0.666        0.8510   0.420          0.534000    0.1100    -6.699
# 1         0.710        0.0822   0.683          0.000169    0.1010    -5.640
# 2         0.836        0.2720   0.564          0.000537    0.1100    -7.127
# 3         0.894        0.7980   0.611          0.000187    0.0964    -4.961
# 4         0.702        0.1160   0.833          0.910000    0.3480    -6.044
# 5         0.803        0.1270   0.525          0.000007    0.1290   -10.034
# 6         0.818        0.4520   0.587          0.004490    0.5900    -9.840
# 7         0.808        0.6080   0.300          0.000048    0.0863   -11.213
# 8         0.846        0.2140   0.669          0.467000    0.0857    -7.822
# 9         0.555        0.9120   0.295          0.275000    0.0967   -11.038
#
#    speechiness    tempo  time_signature  emotion
# 0       0.0829  133.015               5  Neutral
# 1       0.3600  129.993               3  Excited
# 2       0.0424  130.005               4  Neutral
# 3       0.1130  111.087               4  Neutral
# 4       0.0447  105.115               4    Happy
# 5       0.1970  100.103               4  Neutral
# 6       0.1990   95.842               4  Neutral
# 7       0.0453  119.964               4  Neutral
# 8       0.0441  115.008               4  Neutral
# 9       0.0360   77.033               4  Neutral

# %%
# dropping missing values
df_new_data.dropna()
# Out:
#      danceability  acousticness  energy  instrumentalness  liveness  loudness  \
# 0           0.666        0.8510   0.420          0.534000    0.1100    -6.699
# 1           0.710        0.0822   0.683          0.000169    0.1010    -5.640
# 2           0.836        0.2720   0.564          0.000537    0.1100    -7.127
# 3           0.894        0.7980   0.611          0.000187    0.0964    -4.961
# 4           0.702        0.1160   0.833          0.910000    0.3480    -6.044
# ..            ...           ...     ...               ...       ...       ...
# 525         0.735        0.6320   0.918          0.193000    0.0718    -2.582
# 526         0.602        0.1770   0.883          0.000004    0.1190    -6.183
# 527         0.729        0.2380   0.864          0.000000    0.1950    -3.942
# 528         0.809        0.0490   0.806          0.000000    0.0659    -6.547
# 529         0.816        0.1140   0.961          0.008500    0.1370    -2.204
#
#      speechiness    tempo  time_signature  emotion
# 0         0.0829  133.015               5  Neutral
# 1         0.3600  129.993               3  Excited
# 2         0.0424  130.005               4  Neutral
# 3         0.1130  111.087               4  Neutral
# 4         0.0447  105.115               4    Happy
# ..           ...      ...             ...      ...
# 525       0.0355  127.954               4    Happy
# 526       0.0778  154.010               4    Happy
# 527       0.0668  121.058               4    Happy
# 528       0.2340  123.997               4    Happy
# 529       0.1390  106.972               4    Happy
#
# [530 rows x 10 columns]

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
# Encode Emotion Labels
label_encoder = LabelEncoder()
df_new_data['emotion'] = label_encoder.fit_transform(df['emotion'])

# %%
df_new_data.head(10)
# Out:
#    danceability  acousticness  energy  instrumentalness  liveness  loudness  \
# 0         0.666        0.8510   0.420          0.534000    0.1100    -6.699
# 1         0.710        0.0822   0.683          0.000169    0.1010    -5.640
# 2         0.836        0.2720   0.564          0.000537    0.1100    -7.127
# 3         0.894        0.7980   0.611          0.000187    0.0964    -4.961
# 4         0.702        0.1160   0.833          0.910000    0.3480    -6.044
# 5         0.803        0.1270   0.525          0.000007    0.1290   -10.034
# 6         0.818        0.4520   0.587          0.004490    0.5900    -9.840
# 7         0.808        0.6080   0.300          0.000048    0.0863   -11.213
# 8         0.846        0.2140   0.669          0.467000    0.0857    -7.822
# 9         0.555        0.9120   0.295          0.275000    0.0967   -11.038
#
#    speechiness    tempo  time_signature  emotion
# 0       0.0829  133.015               5        3
# 1       0.3600  129.993               3        1
# 2       0.0424  130.005               4        3
# 3       0.1130  111.087               4        3
# 4       0.0447  105.115               4        2
# 5       0.1970  100.103               4        3
# 6       0.1990   95.842               4        3
# 7       0.0453  119.964               4        3
# 8       0.0441  115.008               4        3
# 9       0.0360   77.033               4        3

# %%
# Select Features & Target
X = df_new_data.drop(columns=['emotion'])
y = df_new_data['emotion']

# %%
# Scale Features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[-0.64405173,  2.81336503, -2.29540567, ..., -0.51532247,
#          0.70339004,  3.03914122],
#        [-0.26930034, -0.88021579, -0.52308752, ...,  2.46902286,
#          0.57477461, -2.95990849],
#        [ 0.80385138,  0.03164899, -1.32501094, ..., -0.9515043 ,
#          0.57528532,  0.03961637],
#        ...,
#        [-0.10747587, -0.13169876,  0.69664475, ..., -0.68871821,
#          0.19450364,  0.03961637],
#        [ 0.5738903 , -1.03972006,  0.30579132, ...,  1.11201271,
#          0.31958661,  0.03961637],
#        [ 0.63350984, -0.7274376 ,  1.35031342, ...,  0.08887014,
#         -0.40499238,  0.03961637]])

# %%
from sklearn.model_selection import train_test_split
# Split Dataset
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Reshape for LSTM (Adding a time step dimension)
time_steps = 1  # Since we treat each song as a single sequence
X_train_reshaped = X_train.reshape((X_train.shape[0], time_steps, X_train.shape[1]))
X_test_reshaped = X_test.reshape((X_test.shape[0], time_steps, X_test.shape[1]))

# %% [markdown]
# Model training

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Conv1D, Flatten, Reshape
# Define Deep Learning Model (Hybrid CNN + LSTM)
model = Sequential([
    Reshape((time_steps, X_train.shape[1]), input_shape=(time_steps, X_train.shape[1])),
    LSTM(64, return_sequences=True),
    Dropout(0.2),
    LSTM(32),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(len(label_encoder.classes_), activation='softmax')  # Number of emotion categories
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/reshape.py:39: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Compile Model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train Model
model.fit(X_train_reshaped, y_train, epochs=30, batch_size=16, validation_data=(X_test_reshaped, y_test))

# Evaluate Model
loss, accuracy = model.evaluate(X_test_reshaped, y_test)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# Epoch 1/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.9709 - loss: 0.1214 - val_accuracy: 0.9434 - val_loss: 0.1799
# Epoch 2/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9409 - loss: 0.1897 - val_accuracy: 0.9245 - val_loss: 0.1975
# Epoch 3/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9485 - loss: 0.1544 - val_accuracy: 0.9340 - val_loss: 0.1800
# Epoch 4/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9568 - loss: 0.1306 - val_accuracy: 0.9340 - val_loss: 0.1779
# Epoch 5/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9753 - loss: 0.1109 - val_accuracy: 0.9245 - val_loss: 0.1840
# Epoch 6/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9528 - loss: 0.1395 - val_accuracy: 0.9434 - val_loss: 0.1826
# Epoch 7/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9691 - loss: 0.0967 - val_accuracy: 0.9434 - val_loss: 0.1824
# Epoch 8/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9255 - loss: 0.1754 - val_accuracy: 0.9434 - val_loss: 0.1764
# Epoch 9/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9693 - loss: 0.0949 - val_accuracy: 0.9434 - val_loss: 0.1843
# Epoch 10/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9717 - loss: 0.0926 - val_accuracy: 0.9434 - val_loss: 0.1691
# Epoch 11/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9502 - loss: 0.1471 - val_accuracy: 0.9434 - val_loss: 0.1668
# Epoch 12/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9647 - loss: 0.1074 - val_accuracy: 0.9434 - val_loss: 0.1774
# Epoch 13/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9431 - loss: 0.1467 - val_accuracy: 0.9528 - val_loss: 0.1623
# Epoch 14/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9633 - loss: 0.0961 - val_accuracy: 0.9528 - val_loss: 0.1666
# Epoch 15/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9473 - loss: 0.1360 - val_accuracy: 0.9434 - val_loss: 0.1859
# Epoch 16/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9621 - loss: 0.1017 - val_accuracy: 0.9528 - val_loss: 0.1719
# Epoch 17/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9464 - loss: 0.1234 - val_accuracy: 0.9528 - val_loss: 0.1731
# Epoch 18/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9380 - loss: 0.1498 - val_accuracy: 0.9434 - val_loss: 0.1843
# Epoch 19/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9633 - loss: 0.1101 - val_accuracy: 0.9434 - val_loss: 0.1839
# Epoch 20/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9737 - loss: 0.0741 - val_accuracy: 0.9434 - val_loss: 0.1849
# Epoch 21/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9464 - loss: 0.1097 - val_accuracy: 0.9340 - val_loss: 0.2085
# Epoch 22/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9708 - loss: 0.0785 - val_accuracy: 0.9434 - val_loss: 0.1852
# Epoch 23/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9561 - loss: 0.0908 - val_accuracy: 0.9340 - val_loss: 0.1809
# Epoch 24/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9464 - loss: 0.1039 - val_accuracy: 0.9434 - val_loss: 0.1793
# Epoch 25/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9817 - loss: 0.0572 - val_accuracy: 0.9340 - val_loss: 0.1894
# Epoch 26/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9716 - loss: 0.0903 - val_accuracy: 0.9434 - val_loss: 0.1901
# Epoch 27/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9664 - loss: 0.0887 - val_accuracy: 0.9434 - val_loss: 0.1999
# Epoch 28/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9757 - loss: 0.0634 - val_accuracy: 0.9623 - val_loss: 0.1847
# Epoch 29/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9790 - loss: 0.0724 - val_accuracy: 0.9340 - val_loss: 0.2121
# Epoch 30/30
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9634 - loss: 0.0869 - val_accuracy: 0.9340 - val_loss: 0.2074
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9423 - loss: 0.1764
# Test Accuracy: 0.9340

# %%
import joblib

# Save the StandardScaler
joblib.dump(scaler, "scaler.pkl")

# Save the LabelEncoder
joblib.dump(label_encoder, "label_encoder.pkl")
# Out:
# ['label_encoder.pkl']

# %%
model.save("Final_Final_test.keras")  # Saves the entire model (architecture + weights)

# %% [markdown]
# Testing Model

# %%
from tensorflow import keras
Model = keras.models.load_model("/content/Final_Final_test.keras")

# %%
new_data = pd.read_csv("/content/nigerian_spotify_songs1 (1).csv")

# %%
# Drop non-numeric columns that aren't useful for modeling
cols_to_drop = ['name', 'album', 'artist', 'artist_top_genre', 'release_date', 'length', 'popularity']
new_data_drop = new_data.drop(columns=[col for col in cols_to_drop if col in new_data.columns], errors='ignore')

# %%
new_data_drop.head(10)
# Out:
#    danceability  acousticness  energy  instrumentalness  liveness  loudness  \
# 0         0.666        0.8510   0.420          0.534000    0.1100    -6.699
# 1         0.710        0.0822   0.683          0.000169    0.1010    -5.640
# 2         0.836        0.2720   0.564          0.000537    0.1100    -7.127
# 3         0.894        0.7980   0.611          0.000187    0.0964    -4.961
# 4         0.702        0.1160   0.833          0.910000    0.3480    -6.044
# 5         0.803        0.1270   0.525          0.000007    0.1290   -10.034
# 6         0.818        0.4520   0.587          0.004490    0.5900    -9.840
# 7         0.808        0.6080   0.300          0.000048    0.0863   -11.213
# 8         0.846        0.2140   0.669          0.467000    0.0857    -7.822
# 9         0.555        0.9120   0.295          0.275000    0.0967   -11.038
#
#    speechiness    tempo  time_signature
# 0       0.0829  133.015               5
# 1       0.3600  129.993               3
# 2       0.0424  130.005               4
# 3       0.1130  111.087               4
# 4       0.0447  105.115               4
# 5       0.1970  100.103               4
# 6       0.1990   95.842               4
# 7       0.0453  119.964               4
# 8       0.0441  115.008               4
# 9       0.0360   77.033               4

# %%
from sklearn.preprocessing import StandardScaler
import joblib

scaler = joblib.load("/content/scaler.pkl")  # Load the scaler used during training
new_data_scaled = scaler.transform(new_data_drop)

# Reshape new data to match model input (samples, time steps, features)
new_data_reshaped = new_data_scaled.reshape((new_data_scaled.shape[0], 1, new_data_scaled.shape[1]))

# Make predictions
predictions = model.predict(new_data_reshaped)
print(predictions)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# [[2.4786659e-05 2.0639177e-02 1.3863863e-04 9.7884423e-01 3.5319728e-04]
#  [4.9740449e-02 8.7398666e-01 2.1380525e-02 5.0912481e-02 3.9799013e-03]
#  [1.8575680e-03 2.1159817e-01 4.9740663e-03 7.5685304e-01 2.4717042e-02]
#  ...
#  [1.6245422e-05 1.7826556e-09 9.9998373e-01 2.5548090e-08 8.8716461e-15]
#  [2.3633167e-05 2.2239627e-08 9.9997640e-01 3.8157054e-08 9.3283908e-14]
#  [4.0299267e-07 2.5830184e-12 9.9999964e-01 6.3342290e-11 2.8095420e-19]]

# %%
# Get predicted class indices (0 to 4)
predicted_classes = predictions.argmax(axis=1)

# %%
# Decode back to emotion labels
predicted_emotions = label_encoder.inverse_transform(predicted_classes)

# %%
# View result
print(predicted_emotions)
# Out:
# ['Neutral' 'Excited' 'Neutral' 'Neutral' 'Happy' 'Neutral' 'Neutral'
#  'Neutral' 'Neutral' 'Neutral' 'Neutral' 'Excited' 'Neutral' 'Neutral'
#  'Neutral' 'Neutral' 'Excited' 'Excited' 'Happy' 'Neutral' 'Neutral'
#  'Neutral' 'Neutral' 'Neutral' 'Happy' 'Neutral' 'Neutral' 'Excited'
#  'Neutral' 'Happy' 'Neutral' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy'
#  'Happy' 'Neutral' 'Happy' 'Happy' 'Neutral' 'Neutral' 'Neutral' 'Happy'
#  'Happy' 'Happy' 'Neutral' 'Neutral' 'Neutral' 'Happy' 'Neutral' 'Angry'
#  'Happy' 'Neutral' 'Neutral' 'Happy' 'Happy' 'Happy' 'Happy' 'Neutral'
#  'Happy' 'Happy' 'Happy' 'Happy' 'Neutral' 'Happy' 'Excited' 'Neutral'
#  'Neutral' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Neutral' 'Happy'
#  'Happy' 'Neutral' 'Happy' 'Neutral' 'Neutral' 'Happy' 'Happy' 'Happy'
#  'Happy' 'Neutral' 'Happy' 'Happy' 'Happy' 'Happy' 'Neutral' 'Happy'
#  'Excited' 'Angry' 'Happy' 'Happy' 'Angry' 'Happy' 'Happy' 'Angry'
#  'Neutral' 'Neutral' 'Happy' 'Happy' 'Excited' 'Happy' 'Happy' 'Happy'
#  'Happy' 'Neutral' 'Excited' 'Happy' 'Neutral' 'Happy' 'Happy' 'Happy'
#  'Happy' 'Happy' 'Happy' 'Happy' 'Neutral' 'Happy' 'Happy' 'Happy' 'Angry'
#  'Excited' 'Neutral' 'Neutral' 'Happy' 'Excited' 'Happy' 'Happy' 'Happy'
#  'Neutral' 'Happy' 'Happy' 'Happy' 'Neutral' 'Neutral' 'Happy' 'Angry'
#  'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Neutral' 'Happy' 'Excited'
#  'Happy' 'Happy' 'Neutral' 'Happy' 'Neutral' 'Neutral' 'Angry' 'Happy'
#  'Neutral' 'Happy' 'Happy' 'Neutral' 'Neutral' 'Happy' 'Happy' 'Happy'
#  'Happy' 'Neutral' 'Neutral' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy'
#  'Excited' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Excited'
#  'Happy' 'Happy' 'Happy' 'Happy' 'Neutral' 'Neutral' 'Happy' 'Happy'
#  'Excited' 'Angry' 'Neutral' 'Neutral' 'Angry' 'Happy' 'Happy' 'Neutral'
#  'Angry' 'Happy' 'Happy' 'Happy' 'Angry' 'Neutral' 'Happy' 'Happy' 'Happy'
#  'Neutral' 'Happy' 'Happy' 'Happy' 'Happy' 'Neutral' 'Happy' 'Neutral'
#  'Angry' 'Neutral' 'Neutral' 'Angry' 'Neutral' 'Neutral' 'Neutral' 'Happy'
#  'Neutral' 'Neutral' 'Happy' 'Excited' 'Neutral' 'Neutral' 'Happy'
#  'Excited' 'Happy' 'Happy' 'Happy' 'Happy' 'Neutral' 'Happy' 'Neutral'
#  'Neutral' 'Neutral' 'Happy' 'Happy' 'Happy' 'Neutral' 'Happy' 'Neutral'
#  'Happy' 'Happy' 'Happy' 'Happy' 'Neutral' 'Happy' 'Happy' 'Neutral'
#  'Neutral' 'Happy' 'Happy' 'Happy' 'Happy' 'Neutral' 'Neutral' 'Excited'
#  'Happy' 'Happy' 'Excited' 'Neutral' 'Happy' 'Happy' 'Happy' 'Neutral'
#  'Neutral' 'Neutral' 'Happy' 'Neutral' 'Neutral' 'Happy' 'Neutral' 'Happy'
#  'Neutral' 'Happy' 'Happy' 'Happy' 'Happy' 'Neutral' 'Happy' 'Neutral'
#  'Angry' 'Happy' 'Happy' 'Neutral' 'Happy' 'Neutral' 'Excited' 'Excited'
#  'Neutral' 'Neutral' 'Happy' 'Happy' 'Neutral' 'Happy' 'Happy' 'Happy'
#  'Happy' 'Happy' 'Neutral' 'Happy' 'Happy' 'Neutral' 'Happy' 'Happy'
#  'Neutral' 'Neutral' 'Neutral' 'Happy' 'Happy' 'Happy' 'Neutral' 'Angry'
#  'Happy' 'Happy' 'Happy' 'Neutral' 'Happy' 'Happy' 'Happy' 'Neutral'
#  'Happy' 'Happy' 'Neutral' 'Neutral' 'Neutral' 'Happy' 'Excited' 'Happy'
#  'Neutral' 'Neutral' 'Happy' 'Happy' 'Happy' 'Neutral' 'Happy' 'Excited'
#  'Neutral' 'Neutral' 'Happy' 'Happy' 'Happy' 'Neutral' 'Neutral' 'Happy'
#  'Neutral' 'Happy' 'Neutral' 'Happy' 'Happy' 'Happy' 'Happy' 'Angry'
#  'Neutral' 'Neutral' 'Angry' 'Happy' 'Angry' 'Happy' 'Happy' 'Happy'
#  'Neutral' 'Happy' 'Happy' 'Happy' 'Neutral' 'Happy' 'Happy' 'Happy'
#  'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Angry'
#  'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Neutral'
#  'Happy' 'Angry' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy'
#  'Happy' 'Neutral' 'Neutral' 'Angry' 'Happy' 'Angry' 'Happy' 'Happy'
#  'Neutral' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy'
#  'Happy' 'Happy' 'Neutral' 'Neutral' 'Happy' 'Neutral' 'Happy' 'Happy'
#  'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Angry' 'Happy' 'Neutral'
#  'Neutral' 'Happy' 'Happy' 'Angry' 'Happy' 'Happy' 'Excited' 'Happy'
#  'Neutral' 'Happy' 'Happy' 'Excited' 'Neutral' 'Happy' 'Neutral' 'Happy'
#  'Neutral' 'Neutral' 'Happy' 'Neutral' 'Neutral' 'Neutral' 'Neutral'
#  'Happy' 'Happy' 'Neutral' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy'
#  'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Neutral' 'Happy' 'Angry' 'Happy'
#  'Neutral' 'Neutral' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Neutral'
#  'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Angry' 'Happy' 'Happy' 'Happy'
#  'Neutral' 'Happy' 'Angry' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy'
#  'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy' 'Excited'
#  'Happy' 'Happy' 'Happy' 'Happy' 'Neutral' 'Happy' 'Happy' 'Neutral'
#  'Happy' 'Angry' 'Happy' 'Neutral' 'Happy' 'Happy' 'Happy' 'Happy' 'Happy'
#  'Happy' 'Happy' 'Happy' 'Happy']

# %%
# Create a DataFrame for predicted emotions
import pandas as pd  # Make sure pandas is imported
print_df = pd.DataFrame({'predicted_emotions': predicted_emotions})

# %%
print_df.to_csv("emotion_predictions.csv", index=False)
